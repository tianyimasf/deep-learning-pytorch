# %%
import numpy as np
import torch
torch.set_printoptions(edgeitems=2, threshold=50)

# %% [markdown]
# Data source: https://www.kaggle.com/datasets/amritpal333/adni4dicomnano10514

# %%
import imageio

# custom dataset
dir_path = "../data/p1ch4/ADNI4-DICOM-nano-10514/002_S_0413/Axial_3TE_T2_STAR/2019-08-27_09_39_37.0/S868724"
vol_arr = imageio.volread(dir_path, 'DICOM')
vol_arr.shape
# Out:
# Reading DICOM (examining files): 1/44 files (2.3%44/44 files (100.0%)
#   Found 1 correct series.
# Reading DICOM (loading data): 44/44  (100.0%)
# (44, 256, 256)

# %%
vol = torch.from_numpy(vol_arr).float()
vol = torch.unsqueeze(vol, 0)

vol.shape
# Out:
# torch.Size([1, 44, 256, 256])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.imshow(vol_arr[10])

# %%
plt.imshow(vol_arr[11])
